# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Mod-4-Project---Starter-Notebook" data-toc-modified-id="Mod-4-Project---Starter-Notebook-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Mod 4 Project - Starter Notebook</a></span></li><li><span><a href="#Some-Notes-Before-Starting" data-toc-modified-id="Some-Notes-Before-Starting-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Some Notes Before Starting</a></span><ul class="toc-item"><li><span><a href="#Wide-Format-vs-Long-Format" data-toc-modified-id="Wide-Format-vs-Long-Format-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Wide Format vs Long Format</a></span></li></ul></li><li><span><a href="#Helper-Functions-Provided" data-toc-modified-id="Helper-Functions-Provided-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Helper Functions Provided</a></span></li><li><span><a href="#Step-1:-Load-the-Data/Filtering-for-Chosen-Zipcodes" data-toc-modified-id="Step-1:-Load-the-Data/Filtering-for-Chosen-Zipcodes-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Step 1: Load the Data/Filtering for Chosen Zipcodes</a></span><ul class="toc-item"><li><span><a href="#Raw-Difference-and-Percent-Change-of-median-house-prices-from-April-2013-to-April-2018" data-toc-modified-id="Raw-Difference-and-Percent-Change-of-median-house-prices-from-April-2013-to-April-2018-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Raw Difference and Percent Change of median house prices from April 2013 to April 2018</a></span></li><li><span><a href="#Set-index-as-Zip-Code" data-toc-modified-id="Set-index-as-Zip-Code-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Set index as Zip Code</a></span></li><li><span><a href="#New-df's-for-top-10-raw-and-percent-increase-by-median-house-price" data-toc-modified-id="New-df's-for-top-10-raw-and-percent-increase-by-median-house-price-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>New df's for top 10 raw and percent increase by median house price</a></span></li><li><span><a href="#No-duplicates-in-top-10-zip-codes-by-raw-and-percent-increase." data-toc-modified-id="No-duplicates-in-top-10-zip-codes-by-raw-and-percent-increase.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>No duplicates in top 10 zip codes by raw and percent increase.</a></span></li><li><span><a href="#Concatenate-raw-and-percent-df's" data-toc-modified-id="Concatenate-raw-and-percent-df's-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Concatenate raw and percent df's</a></span></li><li><span><a href="#Check-for-missing-data" data-toc-modified-id="Check-for-missing-data-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Check for missing data</a></span></li><li><span><a href="#There-is-a-large-amount-of-missing-data-in-5-columns" data-toc-modified-id="There-is-a-large-amount-of-missing-data-in-5-columns-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>There is a large amount of missing data in 5 columns</a></span></li><li><span><a href="#Final-15-Zip-Codes" data-toc-modified-id="Final-15-Zip-Codes-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Final 15 Zip Codes</a></span><ul class="toc-item"><li><span><a href="#No-missing-data-remains" data-toc-modified-id="No-missing-data-remains-4.8.1"><span class="toc-item-num">4.8.1&nbsp;&nbsp;</span>No missing data remains</a></span></li></ul></li></ul></li><li><span><a href="#Step-3:-Exporatory-Data-Analysis-and-Visualization" data-toc-modified-id="Step-3:-Exporatory-Data-Analysis-and-Visualization-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Step 3: Exporatory Data Analysis and Visualization</a></span><ul class="toc-item"><li><span><a href="#Add-melt_data-function-to-melt-data-for-visualization" data-toc-modified-id="Add-melt_data-function-to-melt-data-for-visualization-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Add melt_data function to melt data for visualization</a></span></li><li><span><a href="#Practicing-with-.melt-function" data-toc-modified-id="Practicing-with-.melt-function-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Practicing with .melt function</a></span></li><li><span><a href="#Concatenate-melted-zips" data-toc-modified-id="Concatenate-melted-zips-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Concatenate melted zips</a></span><ul class="toc-item"><li><span><a href="#Practice-for-creating-loop" data-toc-modified-id="Practice-for-creating-loop-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Practice for creating loop</a></span></li><li><span><a href="#Practice-melt-and-concatenate" data-toc-modified-id="Practice-melt-and-concatenate-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Practice melt and concatenate</a></span></li></ul></li><li><span><a href="#Plot-median-house-price-by-date-for-15-zip-codes" data-toc-modified-id="Plot-median-house-price-by-date-for-15-zip-codes-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Plot median house price by date for 15 zip codes</a></span></li><li><span><a href="#Plot-low-and-high-value-zip-code-charts" data-toc-modified-id="Plot-low-and-high-value-zip-code-charts-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Plot low and high value zip code charts</a></span><ul class="toc-item"><li><span><a href="#Practice-trying-to-drop-columns-with-spaces" data-toc-modified-id="Practice-trying-to-drop-columns-with-spaces-5.5.1"><span class="toc-item-num">5.5.1&nbsp;&nbsp;</span>Practice trying to drop columns with spaces</a></span></li></ul></li></ul></li><li><span><a href="#Step-5:-SARIMA-Modeling" data-toc-modified-id="Step-5:-SARIMA-Modeling-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Step 5: SARIMA Modeling</a></span><ul class="toc-item"><li><span><a href="#Parameter-Selection-for-the-ARIMA-Time-Series-Model" data-toc-modified-id="Parameter-Selection-for-the-ARIMA-Time-Series-Model-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Parameter Selection for the ARIMA Time Series Model</a></span></li></ul></li><li><span><a href="#Step-6:-Interpreting-Results" data-toc-modified-id="Step-6:-Interpreting-Results-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Step 6: Interpreting Results</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Dynamic-Forecasting" data-toc-modified-id="Dynamic-Forecasting-7.0.1"><span class="toc-item-num">7.0.1&nbsp;&nbsp;</span>Dynamic Forecasting</a></span></li></ul></li><li><span><a href="#Producing-and-Visualizing-Forecasts" data-toc-modified-id="Producing-and-Visualizing-Forecasts-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Producing and Visualizing Forecasts</a></span></li></ul></li></ul></div>

# %%
# Import necessary libraries
import warnings
warnings.filterwarnings('ignore')
import itertools
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
plt.style.use('ggplot')

# %% [markdown]
# # Mod 4 Project - Starter Notebook
#
# This notebook has been provided to you so that you can make use of the following starter code to help with the trickier parts of preprocessing the Zillow dataset.
#
# The notebook contains a rough outline the general order you'll likely want to take in this project. You'll notice that most of the areas are left blank. This is so that it's more obvious exactly when you should make use of the starter code provided for preprocessing.
#
# **_NOTE:_** The number of empty cells are not meant to infer how much or how little code should be involved in any given step--we've just provided a few for your convenience. Add, delete, and change things around in this notebook as needed!
#
# # Some Notes Before Starting
#
# This project will be one of the more challenging projects you complete in this program. This is because working with Time Series data is a bit different than working with regular datasets. In order to make this a bit less frustrating and help you understand what you need to do (and when you need to do it), we'll quickly review the dataset formats that you'll encounter in this project.
#
# ## Wide Format vs Long Format
#
# If you take a look at the format of the data in `zillow_data.csv`, you'll notice that the actual Time Series values are stored as separate columns. Here's a sample:
#
# <img src='https://raw.githubusercontent.com/learn-co-students/dsc-mod-4-project-seattle-ds-102819/master/images/df_head.png'>
#
# You'll notice that the first seven columns look like any other dataset you're used to working with. However, column 8 refers to the median housing sales values for April 1996, column 9 for May 1996, and so on. This This is called **_Wide Format_**, and it makes the dataframe intuitive and easy to read. However, there are problems with this format when it comes to actually learning from the data, because the data only makes sense if you know the name of the column that the data can be found it. Since column names are metadata, our algorithms will miss out on what dates each value is for. This means that before we pass this data to our ARIMA model, we'll need to reshape our dataset to **_Long Format_**. Reshaped into long format, the dataframe above would now look like:
#
# <img src='https://raw.githubusercontent.com/learn-co-students/dsc-mod-4-project-seattle-ds-102819/master/images/melted1.png'>
#
# There are now many more rows in this dataset--one for each unique time and zipcode combination in the data! Once our dataset is in this format, we'll be able to train an ARIMA model on it. The method used to convert from Wide to Long is `pd.melt()`, and it is common to refer to our dataset as 'melted' after the transition to denote that it is in long format.
#
# # Helper Functions Provided
#
# Melting a dataset can be tricky if you've never done it before, so you'll see that we have provided a sample function, `melt_data()`, to help you with this step below. Also provided is:
#
# * `get_datetimes()`, a function to deal with converting the column values for datetimes as a pandas series of datetime objects
# * Some good parameters for matplotlib to help make your visualizations more readable.
#
# Good luck!
#
#
# # Step 1: Load the Data/Filtering for Chosen Zipcodes

# %%
df = pd.read_csv('zillow_data.csv')
df.head(10)
# Out:
#    RegionID  RegionName           City State              Metro  \
# 0     84654       60657        Chicago    IL            Chicago
# 1     90668       75070       McKinney    TX  Dallas-Fort Worth
# 2     91982       77494           Katy    TX            Houston
# 3     84616       60614        Chicago    IL            Chicago
# 4     93144       79936        El Paso    TX            El Paso
# 5     91733       77084        Houston    TX            Houston
# 6     61807       10467       New York    NY           New York
# 7     84640       60640        Chicago    IL            Chicago
# 8     91940       77449           Katy    TX            Houston
# 9     97564       94109  San Francisco    CA      San Francisco
#
#       CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-07  \
# 0           Cook         1  334200.0  335400.0  336500.0  ...  1005500
# 1         Collin         2  235700.0  236900.0  236700.0  ...   308000
# ...

# %% [markdown]
# ## Raw Difference and Percent Change of median house prices from April 2013 to April 2018
# * I chose to use the final five years of the data set to optimize for recent trends, and because 5 years is a more optimal investment horizon than 20 years.
#
# * I wonder if I should be using data from post 2009 real estate crash?
#     * Maybe experiment with modeling price change from 2011/2012?

# %%
# make copy of df
df1 = df.copy()

# add column with difference between 2017 and 1996 average value
df1['Raw Difference'] = df['2018-04'] - df['2012-04']

# add column with percent change between 2017 and 1996 average value
df1['Percent Change'] = (df['2018-04'] / df['2012-04']) * 100

df1.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-09  2017-10  2017-11  \
# 0         1  334200.0  335400.0  336500.0  ...  1007800  1009600  1013300
# 1         2  235700.0  236900.0  236700.0  ...   312500   314100   315000
# 2         3  210400.0  212200.0  212200.0  ...   320200   320400   320800
# 3         4  498100.0  500900.0  503100.0  ...  1287400  1291500  1296600
# 4         5   77300.0   77300.0   77300.0  ...   120000   120300   120300
#
#    2017-12  2018-01  2018-02  2018-03  2018-04  Raw Difference  Percent Change
# ...

# %% [markdown]
# ## Set index as Zip Code

# %%
# Rename RegionName as ZipCode
df1 = df1.rename(columns={"RegionName": "ZipCode"})

# Set Index as ZipCode
# df1.set_index('ZipCode', inplace=True)

df1.head()
# Out:
#    RegionID  ZipCode      City State              Metro CountyName  SizeRank  \
# 0     84654    60657   Chicago    IL            Chicago       Cook         1
# 1     90668    75070  McKinney    TX  Dallas-Fort Worth     Collin         2
# 2     91982    77494      Katy    TX            Houston     Harris         3
# 3     84616    60614   Chicago    IL            Chicago       Cook         4
# 4     93144    79936   El Paso    TX            El Paso    El Paso         5
#
#     1996-04   1996-05   1996-06  ...  2017-09  2017-10  2017-11  2017-12  \
# 0  334200.0  335400.0  336500.0  ...  1007800  1009600  1013300  1018700
# 1  235700.0  236900.0  236700.0  ...   312500   314100   315000   316600
# 2  210400.0  212200.0  212200.0  ...   320200   320400   320800   321200
# 3  498100.0  500900.0  503100.0  ...  1287400  1291500  1296600  1299000
# 4   77300.0   77300.0   77300.0  ...   120000   120300   120300   120300
#
# ...

# %%
# create new dataframe with top 10 zip codes for Raw Increase and 
# top ten zip codes for Percent Change

df_raw = df1.sort_values('Raw Difference',ascending = False)
print('Raw Difference:\n',df_raw.head(10))

print()

df_percent = df1.sort_values('Percent Change',ascending = False)
print('Percent Change:\n',df_percent.head(10))
# Out:
# Raw Difference:
#         RegionID  ZipCode           City State                           Metro  \
# 272       61635    10021       New York    NY                        New York
# 10237     97518    94027       Atherton    CA                   San Francisco
# 20        61625    10011       New York    NY                        New York
# 4816      96086    90210  Beverly Hills    CA  Los Angeles-Long Beach-Anaheim
# 5738      97691    94301      Palo Alto    CA                        San Jose
# 5843      97513    94022      Los Altos    CA                        San Jose
# 2026      97577    94123  San Francisco    CA                   San Francisco
# 4723      72636    33480     Palm Beach    FL           Miami-Fort Lauderdale
# 1534      62028    11217       New York    NY                        New York
# 508       61628    10014       New York    NY                        New York
#
#           CountyName  SizeRank    1996-04    1996-05    1996-06  ...  \
# ...

# %% [markdown]
# ## New df's for top 10 raw and percent increase by median house price

# %%
# new df_raw with only top ten results
df_raw = df_raw.head(10)
df_raw
# Out:
#        RegionID  ZipCode           City State                           Metro  \
# 272       61635    10021       New York    NY                        New York
# 10237     97518    94027       Atherton    CA                   San Francisco
# 20        61625    10011       New York    NY                        New York
# 4816      96086    90210  Beverly Hills    CA  Los Angeles-Long Beach-Anaheim
# 5738      97691    94301      Palo Alto    CA                        San Jose
# 5843      97513    94022      Los Altos    CA                        San Jose
# 2026      97577    94123  San Francisco    CA                   San Francisco
# 4723      72636    33480     Palm Beach    FL           Miami-Fort Lauderdale
# 1534      62028    11217       New York    NY                        New York
# 508       61628    10014       New York    NY                        New York
#
#           CountyName  SizeRank    1996-04    1996-05    1996-06  ...  \
# ...

# %%
# new df_percent with only top ten results
df_percent = df_percent.head(10)
df_percent
# Out:
#       RegionID  ZipCode           City State                  Metro  \
# 1946     94751    85035        Phoenix    AZ                Phoenix
# 1477     97803    94601        Oakland    CA          San Francisco
# 1239     97795    94590        Vallejo    CA                Vallejo
# 2627     72619    33460     Lake Worth    FL  Miami-Fort Lauderdale
# 1681     97808    94606        Oakland    CA          San Francisco
# 1853     97850    94804       Richmond    CA          San Francisco
# 1960     95800    89104      Las Vegas    NV              Las Vegas
# 474      94724    85008        Phoenix    AZ                Phoenix
# 4298     98433    95824     Sacramento    CA             Sacramento
# 2409     72571    33404  Riviera Beach    FL  Miami-Fort Lauderdale
#
#         CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-09  \
# 1946      Maricopa      1947       NaN       NaN       NaN  ...   150800
# ...

# %% [markdown]
# ## No duplicates in top 10 zip codes by raw and percent increase.

# %% [markdown]
# ## Concatenate raw and percent df's

# %%
prospects = pd.concat([df_percent,df_raw])
prospects
# Out:
#        RegionID  ZipCode           City State                           Metro  \
# 1946      94751    85035        Phoenix    AZ                         Phoenix
# 1477      97803    94601        Oakland    CA                   San Francisco
# 1239      97795    94590        Vallejo    CA                         Vallejo
# 2627      72619    33460     Lake Worth    FL           Miami-Fort Lauderdale
# 1681      97808    94606        Oakland    CA                   San Francisco
# 1853      97850    94804       Richmond    CA                   San Francisco
# 1960      95800    89104      Las Vegas    NV                       Las Vegas
# 474       94724    85008        Phoenix    AZ                         Phoenix
# 4298      98433    95824     Sacramento    CA                      Sacramento
# 2409      72571    33404  Riviera Beach    FL           Miami-Fort Lauderdale
# 272       61635    10021       New York    NY                        New York
# ...

# %%
# Remove Raw Difference and Percent Change for melting
prospects = prospects.drop(columns=['Raw Difference', 'Percent Change', 'RegionID'])
prospects
# Out:
#        ZipCode           City State                           Metro  \
# 1946     85035        Phoenix    AZ                         Phoenix
# 1477     94601        Oakland    CA                   San Francisco
# 1239     94590        Vallejo    CA                         Vallejo
# 2627     33460     Lake Worth    FL           Miami-Fort Lauderdale
# 1681     94606        Oakland    CA                   San Francisco
# 1853     94804       Richmond    CA                   San Francisco
# 1960     89104      Las Vegas    NV                       Las Vegas
# 474      85008        Phoenix    AZ                         Phoenix
# 4298     95824     Sacramento    CA                      Sacramento
# 2409     33404  Riviera Beach    FL           Miami-Fort Lauderdale
# 272      10021       New York    NY                        New York
# 10237    94027       Atherton    CA                   San Francisco
# 20       10011       New York    NY                        New York
# ...

# %% [markdown]
# ## Check for missing data

# %%
prospects.isnull().values.any()
# Out:
# True

# %%
print(prospects.isnull().sum().sum())
# Out:
# 555

# %%
count = prospects.isna().sum()
count1 = pd.DataFrame(count)
count1.head(200)
# Out:
#             0
# ZipCode     0
# City        0
# State       0
# Metro       0
# CountyName  0
# ...        ..
# 2012-01     0
# 2012-02     0
# 2012-03     0
# 2012-04     0
# 2012-05     0
#
# [200 rows x 1 columns]

# %% [markdown]
# ## There is a large amount of missing data in 5 columns
# * Due to the predictive nature of this model, I want to remove those rows, as there will still be 15 zip codes to explore.
# * Sadly, this will exclude the New York region, which had some of the higher raw increases.

# %%
# drop from original index
# prospects = prospects.drop([508, 1534, 20, 272, 1946])

# drop from ZipCode index
#prospects = prospects.drop([10014, 11217, 10011, 10021, 85035])
#prospects

# %%
print(prospects.isnull().sum().sum())
# Out:
# 555

# %% [markdown]
# ## Final 15 Zip Codes

# %%
prospects
# Out:
#        ZipCode           City State                           Metro  \
# 1946     85035        Phoenix    AZ                         Phoenix
# 1477     94601        Oakland    CA                   San Francisco
# 1239     94590        Vallejo    CA                         Vallejo
# 2627     33460     Lake Worth    FL           Miami-Fort Lauderdale
# 1681     94606        Oakland    CA                   San Francisco
# 1853     94804       Richmond    CA                   San Francisco
# 1960     89104      Las Vegas    NV                       Las Vegas
# 474      85008        Phoenix    AZ                         Phoenix
# 4298     95824     Sacramento    CA                      Sacramento
# 2409     33404  Riviera Beach    FL           Miami-Fort Lauderdale
# 272      10021       New York    NY                        New York
# 10237    94027       Atherton    CA                   San Francisco
# 20       10011       New York    NY                        New York
# ...

# %% [markdown]
# ### No missing data remains

# %% [markdown]
# # Step 3: Exporatory Data Analysis and Visualization

# %% [markdown]
# ## Add melt_data function to melt data for visualization

# %%
def melt_data(df):
    """
    Takes the zillow_data dataset in wide form or a subset of the zillow_dataset.  
    Returns a long-form datetime dataframe 
    with the datetime column names as the index and the values as the 'values' column.
    
    If more than one row is passes in the wide-form dataset, the values column
    will be the mean of the values from the datetime columns in all of the rows.
    """
    
    melted = pd.melt(df, id_vars=['ZipCode','SizeRank', 'City', 'State', 'Metro', 'CountyName'], var_name='time')
    melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)
    melted = melted.dropna(subset=['value'])
    return melted.groupby('time').aggregate({'value':'mean'})

# %% [markdown]
# ## Practicing with .melt function

# %%
# prospects['ZipCode']

# %%
# mm

# %%
# Practicing with melt function

#mm = pd.melt(prospects, id_vars=['SizeRank', 'City', 'State', 'Metro', 'CountyName'], var_name='time')
#mm['time'] = pd.to_datetime(mm['time'], infer_datetime_format=True)
#mm = mm.dropna(subset=['value'])
#mm = mm.groupby('time')
#mm.ngroups

# %%
#mm.size()

# %%
#mm.last()

# %%
# print median price for each zipcode on same plot
#initial = melt_data(prospects[prospects['ZipCode'] == 94601])

#for zipcode in prospects['ZipCode']:
#    dataframe = prospects.loc[prospects['ZipCode'] == zipcode]
#    melted = melt_data(dataframe)
#    melted_together = pd.concat([melted, initial], join='left')
#    melted_together
    ## df.loc[df['column_name'] == some_value]

# %%
#print(melted_together)

# %% [markdown]
# ## Concatenate melted zips

# %%
#zip1 = prospects.loc[[94601]]
#zip1

#df.loc[df['B'] == 64]

#zip1 = prospects.loc[prospects['ZipCode'] == 94601]
#zip1.head()
# Out:
#       ZipCode     City State          Metro CountyName  SizeRank   1996-04  \
# 1477    94601  Oakland    CA  San Francisco    Alameda      1478  114600.0
#
#        1996-05   1996-06   1996-07  ...  2017-07  2017-08  2017-09  2017-10  \
# 1477  114500.0  114500.0  114400.0  ...   501300   506600   514100   521100
#
#       2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 1477   526700   535800   546900   555000   562000   566700
#
# [1 rows x 271 columns]

# %%
zip1 = prospects.loc[prospects['ZipCode'] == 94601]
m1 = melt_data(zip1)
m1[zip2.iloc[0,1],zip2.iloc[0,2],'94601'] = m1['value']
m1 = m1.drop('value', axis=1)
m1
# Out:
#             (New York, NY, 94601)
# time
# 1996-04-01               114600.0
# 1996-05-01               114500.0
# 1996-06-01               114500.0
# 1996-07-01               114400.0
# 1996-08-01               114400.0
# ...                           ...
# 2017-12-01               535800.0
# 2018-01-01               546900.0
# 2018-02-01               555000.0
# 2018-03-01               562000.0
# 2018-04-01               566700.0
#
# [265 rows x 1 columns]

# %% [markdown]
# ### Practice for creating loop

# %%
# Create dataframe of second zip
#zip2 = prospects.loc[prospects['ZipCode'] == 94590]

# Melt second dataframe
#m2 = melt_data(zip2)

# Change name of value column to provide distinct column names
# in the concatenated df
#m2[zip2.iloc[0,1], zip2.iloc[0,2],str(94590)] = m2['value']
#m2 = m2.drop('value', axis=1)
#m1 = pd.concat([m1,m2], axis=1)
#m1.info()

# %%
m1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Data columns (total 1 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (New York, NY, 94601)  265 non-null    float64
# dtypes: float64(1)
# memory usage: 4.1 KB

# %%
#zip1 = prospects.loc[prospects['ZipCode'] == 94601]
#m1 = melt_data(zip1)
#m1[zip2.iloc[0,1],zip2.iloc[0,2],'94601'] = m1['value']
#m1 = m1.drop('value', axis=1)
#prospects_trimmed = prospects.drop([1477])
#prospects_trimmed

# %%
zip1 = prospects.loc[prospects['ZipCode'] == 94601]
m1 = melt_data(zip1)
m1[zip2.iloc[0,1],zip2.iloc[0,2],'94601'] = m1['value']
m1 = m1.drop('value', axis=1)
prospects_trimmed = prospects.drop([1477])

for zipcode in prospects_trimmed['ZipCode']:
    zip2 = prospects_trimmed.loc[prospects['ZipCode'] == zipcode]
    m2 = melt_data(zip2)
    m2[zip2.iloc[0,1],zip2.iloc[0,2],str(zipcode)] = m2['value']
    m2 = m2.drop('value', axis=1)
    m1 = pd.concat([m1,m2], axis=1)
    m1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Freq: MS
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (New York, NY, 94601)  265 non-null    float64
#  1   (Phoenix, AZ, 85035)   94 non-null     float64
# dtypes: float64(2)
# memory usage: 6.2 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Freq: MS
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (New York, NY, 94601)  265 non-null    float64
#  1   (Phoenix, AZ, 85035)   94 non-null     float64
#  2   (Vallejo, CA, 94590)   265 non-null    float64
# dtypes: float64(3)
# memory usage: 8.3 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Freq: MS
# Data columns (total 4 columns):
# ...

# %%
m1
# Out:
#             (New York, NY, 94601)  (Phoenix, AZ, 85035)  (Vallejo, CA, 94590)  \
# time
# 1996-04-01               114600.0                   NaN              108200.0
# 1996-05-01               114500.0                   NaN              107800.0
# 1996-06-01               114500.0                   NaN              107500.0
# 1996-07-01               114400.0                   NaN              107300.0
# 1996-08-01               114400.0                   NaN              107100.0
# ...                           ...                   ...                   ...
# 2017-12-01               535800.0              156800.0              357100.0
# 2018-01-01               546900.0              158600.0              362500.0
# 2018-02-01               555000.0              160200.0              366900.0
# 2018-03-01               562000.0              161000.0              371600.0
# 2018-04-01               566700.0              161000.0              376100.0
#
# ...

# %% [markdown]
# ### Practice melt and concatenate

# %%
#    zip3 = prospects['ZipCode'] == 94590
#    m2 = melt_data(zip2)
#    m2[str(zipcode)] = m2['value']
#    m2 = m2.drop('value', axis=1)
 #   m1 = pd.concat([m1,m2], axis=1)
  #  m1.info()

# %%
#zip3 = prospects.loc[[94606]]
#m2 = melt_data(zip2)
#m2[str(94606)] = m2['value']
#m2 = m2.drop('value', axis=1)
#m1 = pd.concat([m1,m2], axis=1)
#m1.info()

# %%
#for zipcode in range(0, 14):
#    zip2 = prospects.iloc[[i]]
#    m2 = melt_data(zip2)
#    m2.iloc[[i]] = m2['value']
#    m2 = m2.drop('value', axis=1)
#    m1 = pd.concat([m1,m2], axis=1)
#    m1.info()

# %%
# prospects.index(0)

# %%
# m4 = melt_data(prospects.iloc[[0]])
# prospects.iloc[[0]] = m4['value']
# m4

# %% [markdown]
# ## Plot median house price by date for 15 zip codes
# * Plot on same chart

# %%
m1.plot(figsize=(15, 10))
plt.xlabel('Year', fontsize=20)
plt.ylabel('House Price (million $)', fontsize=20);
plt.title('Median House Price')
plt.show()

# %% [markdown]
# ## Plot low and high value zip code charts
# * Tried dropping columns from m1, but can't due to spaces in titles
#     * The spaces do help with interpretation, so I'll use an older df and re-melt/concatenate

# %%
low_val = df_percent
low_val
# Out:
#       RegionID  ZipCode           City State                  Metro  \
# 1946     94751    85035        Phoenix    AZ                Phoenix
# 1477     97803    94601        Oakland    CA          San Francisco
# 1239     97795    94590        Vallejo    CA                Vallejo
# 2627     72619    33460     Lake Worth    FL  Miami-Fort Lauderdale
# 1681     97808    94606        Oakland    CA          San Francisco
# 1853     97850    94804       Richmond    CA          San Francisco
# 1960     95800    89104      Las Vegas    NV              Las Vegas
# 474      94724    85008        Phoenix    AZ                Phoenix
# 4298     98433    95824     Sacramento    CA             Sacramento
# 2409     72571    33404  Riviera Beach    FL  Miami-Fort Lauderdale
#
#         CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-09  \
# 1946      Maricopa      1947       NaN       NaN       NaN  ...   150800
# ...

# %%
# Remove Raw Difference and Percent Change for melting
low_val = low_val.drop(columns=['Raw Difference', 'Percent Change', 'RegionID'])

zip1 = low_val.loc[low_val['ZipCode'] == 85035]
m1 = melt_data(zip1)
m1[zip2.iloc[0,1],zip2.iloc[0,2],'85035'] = m1['value']
m1 = m1.drop('value', axis=1)
prospects_trimmed = low_val.drop([1946])

for zipcode in prospects_trimmed['ZipCode']:
    zip2 = prospects_trimmed.loc[prospects['ZipCode'] == zipcode]
    m2 = melt_data(zip2)
    m2[zip2.iloc[0,1],zip2.iloc[0,2],str(zipcode)] = m2['value']
    m2 = m2.drop('value', axis=1)
    m1 = pd.concat([m1,m2], axis=1)
    m1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Freq: MS
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (New York, NY, 85035)  94 non-null     float64
#  1   (Oakland, CA, 94601)   265 non-null    float64
# dtypes: float64(2)
# memory usage: 6.2 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Freq: MS
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (New York, NY, 85035)  94 non-null     float64
#  1   (Oakland, CA, 94601)   265 non-null    float64
#  2   (Vallejo, CA, 94590)   265 non-null    float64
# dtypes: float64(3)
# memory usage: 8.3 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Freq: MS
# Data columns (total 4 columns):
# ...

# %% [markdown]
# ### Practice trying to drop columns with spaces

# %%
m1.columns
# Out:
# Index([   ('Palm Beach', 'FL', '94601'),       ('Phoenix', 'AZ', '85035'),
#              ('Vallejo', 'CA', '94590'),    ('Lake Worth', 'FL', '33460'),
#              ('Oakland', 'CA', '94606'),      ('Richmond', 'CA', '94804'),
#            ('Las Vegas', 'NV', '89104'),       ('Phoenix', 'AZ', '85008'),
#           ('Sacramento', 'CA', '95824'), ('Riviera Beach', 'FL', '33404'),
#             ('New York', 'NY', '10021'),      ('Atherton', 'CA', '94027'),
#             ('New York', 'NY', '10011'), ('Beverly Hills', 'CA', '90210'),
#            ('Palo Alto', 'CA', '94301'),     ('Los Altos', 'CA', '94022'),
#        ('San Francisco', 'CA', '94123'),    ('Palm Beach', 'FL', '33480'),
#             ('New York', 'NY', '11217'),      ('New York', 'NY', '10014')],
#       dtype='object')

# %%
m1.iloc[0]
# Out:
# (Palm Beach, FL, 94601)        114600.0
# (Phoenix, AZ, 85035)                NaN
# (Vallejo, CA, 94590)           108200.0
# (Lake Worth, FL, 33460)         59800.0
# (Oakland, CA, 94606)           120400.0
# (Richmond, CA, 94804)          171300.0
# (Las Vegas, NV, 89104)          94800.0
# (Phoenix, AZ, 85008)            61600.0
# (Sacramento, CA, 95824)         73800.0
# (Riviera Beach, FL, 33404)      56800.0
# (New York, NY, 10021)               NaN
# (Atherton, CA, 94027)         1179200.0
# (New York, NY, 10011)               NaN
# (Beverly Hills, CA, 90210)    1015400.0
# (Palo Alto, CA, 94301)         709500.0
# (Los Altos, CA, 94022)         795600.0
# (San Francisco, CA, 94123)     849100.0
# (Palm Beach, FL, 33480)        958400.0
# (New York, NY, 11217)               NaN
# (New York, NY, 10014)               NaN
# Name: 1996-04-01 00:00:00, dtype: float64

# %%
m1.plot(figsize=(15, 10))
plt.xlabel('Year', fontsize=20)
plt.ylabel('House Price (million $)', fontsize=20);
plt.title('Median House Price')
plt.show()

# %%
#m3 = m1.copy()

# %%
# line 2 won't call
#m3['(Palm Beach, FL,94601)']

# line 5 below calls, but won't call on a drop function
#m3[('Palm Beach', 'FL', '94601')]

# %%
# Drop columns with high value for second chart
#m3 = m3.drop(('Palm Beach', 'FL', '94601'), axis=1)
#m3

# %% [markdown]
# # Step 5: SARIMA Modeling

# %%
top_zip_percent_melted.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-7f6f57b66ecd> in <module>
# ----> 1 top_zip_percent_melted.columns
#
# NameError: name 'top_zip_percent_melted' is not defined

# %%
top_zip_percent_melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   value   265 non-null    float64
# dtypes: float64(1)
# memory usage: 4.1 KB

# %%
# Plot the time series
top_zip_percent_melted.plot(figsize=(15, 6))
plt.show()
print(top_zip_percent_melted.head())
# Out:
#                value
# time
# 1996-04-01  149200.0
# 1996-05-01  148400.0
# 1996-06-01  147500.0
# 1996-07-01  146600.0
# 1996-08-01  146000.0

# %% [markdown]
# ## Parameter Selection for the ARIMA Time Series Model
#
# The first step towards fitting an ARIMA model is to find the values of `ARIMA(p,d,q)(P,D,Q)s` that produce the desired output. Selection of these parameters requires domain expertise and time.  We shall first generate small ranges of these parameters and use a "grid search" to iteratively explore different combinations of parameters. For each combination of parameters, we fit a new seasonal ARIMA model with the `SARIMAX()` function from the `statsmodels` library and assess its overall quality.
#
# `SARIMAX` detailed documentation can be viewed [here](https://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.sarimax.SARIMAX.html)
#
# Let's begin by generating example combination of parameters that we wish to use:
#
# - Define p, q, and d parameters to take any value from 0/1 using `range()` function. (Note: We can try larger values which can make our model computationally expensive to run, you can try this as an additional experiment)
# - Generate combinations for `(p,d,q)` using `itertools.product`
# - Similarly, generate seasonal combinations as `(p,d,q)s`. Use s = 12 (constant)
# - Print some example combinations for seasonal ARIMA

# %%
# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 1)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
pdqs = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %%
# Run a grid with pdq and seasonal pdq parameters calculated above and get the best AIC value
ans = []
for comb in pdq:
    for combs in pdqs:
        try:
            mod = sm.tsa.statespace.SARIMAX(top_zip_percent_melted,
                                            order=comb,
                                            seasonal_order=combs,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            output = mod.fit()
            ans.append([comb, combs, output.aic])
            print('ARIMA {} x {}12 : AIC Calculated ={}'.format(comb, combs, output.aic))
        except:
            continue
# Out:
# ARIMA (0, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =7915.493125002127

# %%
# Find the parameters with minimal AIC value
ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'aic'])
ans_df.loc[ans_df['aic'].idxmin()]
# Out:
# pdq         (0, 0, 0)
# pdqs    (0, 0, 0, 12)
# aic           7915.49
# Name: 0, dtype: object

# %%
# Plug the optimal parameter values into a new SARIMAX model
ARIMA_MODEL = sm.tsa.statespace.SARIMAX(top_zip_percent_melted, 
                                        order=(2, 2, 2), 
                                        seasonal_order=(2, 2, 2, 12), 
                                        enforce_stationarity=False, 
                                        enforce_invertibility=False)

# Fit the model and print results
output = ARIMA_MODEL.fit()

print(output.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7562      0.244      3.094      0.002       0.277       1.235
# ar.L2         -0.3148      0.268     -1.173      0.241      -0.841       0.211
# ma.L1         -0.3538      0.259     -1.366      0.172      -0.861       0.154
# ma.L2         -0.4871      0.274     -1.776      0.076      -1.024       0.050
# ar.S.L12      -0.6631      0.344     -1.929      0.054      -1.337       0.011
# ar.S.L24      -0.4251      0.360     -1.181      0.237      -1.130       0.280
# ma.S.L12      -1.1159      0.288     -3.876      0.000      -1.680      -0.552
# ma.S.L24       0.2877      0.265      1.086      0.277      -0.231       0.807
# sigma2      2.214e+08   3.55e-10   6.24e+17      0.000    2.21e+08    2.21e+08
# ...

# %%
# Call plot_diagnostics() on the results calculated above 
output.plot_diagnostics(figsize=(15, 18))
plt.show()

# %% [markdown]
# # Step 6: Interpreting Results

# %%
# Get predictions starting from 01-01-1998 and calculate confidence intervals
pred = output.get_prediction(start=pd.to_datetime('1996-04-01'), dynamic=False)
pred_conf = pred.conf_int()

# %%
pred

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

# Plot observed values
ax = top_zip_percent_melted['1997':].plot(label='observed')

# Plot predicted values
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=0.9)

# Plot the range for confidence intervals
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='g', alpha=0.5)

# Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('CO2 Levels')
plt.legend()

plt.show()

# %%
pred.predicted_mean
# Out:
# 1996-04-01    0.000000e+00
# 1996-05-01    2.911256e+05
# 1996-06-01    9.839237e+04
# 1996-07-01    2.342757e+05
# 1996-08-01    1.535131e+05
#                   ...
# 2017-12-01    1.655794e+06
# 2018-01-01    1.650507e+06
# 2018-02-01    1.677555e+06
# 2018-03-01    1.685036e+06
# 2018-04-01    1.717014e+06
# Freq: MS, Name: predicted_mean, Length: 265, dtype: float64

# %%
top_zip_percent_melted['1996-04-01':].value
# Out:
# time
# 1996-04-01     149200.0
# 1996-05-01     148400.0
# 1996-06-01     147500.0
# 1996-07-01     146600.0
# 1996-08-01     146000.0
#                 ...
# 2017-12-01    1651200.0
# 2018-01-01    1661800.0
# 2018-02-01    1672800.0
# 2018-03-01    1694000.0
# 2018-04-01    1721100.0
# Name: value, Length: 265, dtype: float64

# %%
# Get the real and predicted values
price_forecasted = pred.predicted_mean
price_truth = top_zip_percent_melted['1996-04-01':].value

# Compute the mean square error
mse = ((price_forecasted - price_truth) ** 2).mean()
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 26084.84

# %% [markdown]
# ### Dynamic Forecasting
#
# We can achieve a deeper insight into model's predictive power using dynamic forecasts. In this case, we only use information from the time series up to a certain point, and after that, forecasts are generated using values from previous forecasted time points.

# %%
# Get dynamic predictions with confidence intervals as above 
# Use Dynamic forecasting by setting `dynamic` to True.
pred_dynamic = output.get_prediction(start=pd.to_datetime('1996-04-01'), dynamic=True, full_results=True)
pred_dynamic_conf = pred_dynamic.conf_int()

# %%
# Plot the dynamic forecast with confidence intervals as above

# Plot observed values
ax = top_zip_percent_melted['1997':].plot(label='observed')

# pred_dynamic.predicted_mean.plot(label='Dynamic Forecast', ax=ax)

# ax.fill_between(pred_dynamic_conf.index,
                #pred_dynamic_conf.iloc[:, 0],
                #pred_dynamic_conf.iloc[:, 1], color='g', alpha=.3)

ax.fill_betweenx(ax.get_ylim(), pd.to_datetime('2012-04-01'), price_forecasted.index[-1], alpha=.1, zorder=-1)

ax.set_xlabel('Date')
ax.set_ylabel('Average House Price')

plt.legend()
plt.show()

# %%
# Get forecast 500 steps ahead in future
prediction = output.get_forecast(steps=60)

# Get confidence intervals of forecasts
pred_conf = prediction.conf_int()

# %% [markdown]
# ## Producing and Visualizing Forecasts
#
# We will leverage seasonal ARIMA time series model to forecast future values. The `.get_forecast()` method of the time series output can compute forecasted values for a specified number of steps ahead.

# %%
# Plot future predictions with confidence intervals
ax = top_zip_percent_melted.plot(label='observed', figsize=(20, 15))
prediction.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='k', alpha=0.25)
ax.set_xlabel('Date')
ax.set_ylabel('House Price')

plt.legend()
plt.show()
