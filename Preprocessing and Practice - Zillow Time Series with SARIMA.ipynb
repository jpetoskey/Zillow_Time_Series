# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-Exploration" data-toc-modified-id="Data-Exploration-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data Exploration</a></span><ul class="toc-item"><li><span><a href="#Raw-Difference-and-Percent-Change-of-median-house-prices-from-April-2013-to-April-2018" data-toc-modified-id="Raw-Difference-and-Percent-Change-of-median-house-prices-from-April-2013-to-April-2018-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Raw Difference and Percent Change of median house prices from April 2013 to April 2018</a></span></li></ul></li><li><span><a href="#Preprocessing" data-toc-modified-id="Preprocessing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Set-index-as-Zip-Code" data-toc-modified-id="Set-index-as-Zip-Code-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Set index as Zip Code</a></span></li><li><span><a href="#New-df's-for-top-10-raw-and-percent-increase-by-median-house-price" data-toc-modified-id="New-df's-for-top-10-raw-and-percent-increase-by-median-house-price-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>New df's for top 10 raw and percent increase by median house price</a></span></li><li><span><a href="#No-duplicates-in-top-10-zip-codes-by-raw-and-percent-increase." data-toc-modified-id="No-duplicates-in-top-10-zip-codes-by-raw-and-percent-increase.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>No duplicates in top 10 zip codes by raw and percent increase.</a></span></li><li><span><a href="#Concatenate-raw-and-percent-df's" data-toc-modified-id="Concatenate-raw-and-percent-df's-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Concatenate raw and percent df's</a></span></li><li><span><a href="#Check-for-missing-data" data-toc-modified-id="Check-for-missing-data-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Check for missing data</a></span></li><li><span><a href="#There-is-a-large-amount-of-missing-data-in-5-columns" data-toc-modified-id="There-is-a-large-amount-of-missing-data-in-5-columns-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>There is a large amount of missing data in 5 columns</a></span></li><li><span><a href="#Final-20-Zip-Codes" data-toc-modified-id="Final-20-Zip-Codes-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Final 20 Zip Codes</a></span><ul class="toc-item"><li><span><a href="#Option-to-include-missing-data" data-toc-modified-id="Option-to-include-missing-data-2.7.1"><span class="toc-item-num">2.7.1&nbsp;&nbsp;</span>Option to include missing data</a></span></li></ul></li></ul></li><li><span><a href="#Step-3:-Exporatory-Data-Analysis-and-Visualization" data-toc-modified-id="Step-3:-Exporatory-Data-Analysis-and-Visualization-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Step 3: Exporatory Data Analysis and Visualization</a></span><ul class="toc-item"><li><span><a href="#Melt-and-plot-Median-Price-for-Top-20-Zip-Codes" data-toc-modified-id="Melt-and-plot-Median-Price-for-Top-20-Zip-Codes-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Melt and plot Median Price for Top 20 Zip Codes</a></span><ul class="toc-item"><li><span><a href="#Add-melt_data-function-to-melt-data-for-visualization" data-toc-modified-id="Add-melt_data-function-to-melt-data-for-visualization-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Add melt_data function to melt data for visualization</a></span></li><li><span><a href="#Practicing-with-.melt-function" data-toc-modified-id="Practicing-with-.melt-function-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Practicing with .melt function</a></span></li><li><span><a href="#Concatenate-melted-zips" data-toc-modified-id="Concatenate-melted-zips-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Concatenate melted zips</a></span></li><li><span><a href="#Plot-median-house-price-by-date-for-20-zip-codes" data-toc-modified-id="Plot-median-house-price-by-date-for-20-zip-codes-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Plot median house price by date for 20 zip codes</a></span></li></ul></li><li><span><a href="#Plot-Top-10-Percent-Return-zip-code-charts" data-toc-modified-id="Plot-Top-10-Percent-Return-zip-code-charts-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Plot Top 10 Percent Return zip code charts</a></span><ul class="toc-item"><li><span><a href="#Plot-Median-value-of-Low-Value-housing-by-zip-code" data-toc-modified-id="Plot-Median-value-of-Low-Value-housing-by-zip-code-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Plot Median value of Low-Value housing by zip code</a></span></li></ul></li><li><span><a href="#Plot-Top-10-Raw-Price-Increase-zip-code-charts" data-toc-modified-id="Plot-Top-10-Raw-Price-Increase-zip-code-charts-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Plot Top 10 Raw Price Increase zip code charts</a></span><ul class="toc-item"><li><span><a href="#Plot-Median-value-of-Low-Value-housing-by-zip-code" data-toc-modified-id="Plot-Median-value-of-Low-Value-housing-by-zip-code-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Plot Median value of Low-Value housing by zip code</a></span></li></ul></li></ul></li><li><span><a href="#Select-individual-zip-codes,-build-new-dataframes" data-toc-modified-id="Select-individual-zip-codes,-build-new-dataframes-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Select individual zip codes, build new dataframes</a></span><ul class="toc-item"><li><span><a href="#Top-New-York-and-California-zips-by-raw-increase" data-toc-modified-id="Top-New-York-and-California-zips-by-raw-increase-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Top New York and California zips by raw increase</a></span></li><li><span><a href="#Top-zips-by-percent-increase" data-toc-modified-id="Top-zips-by-percent-increase-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Top zips by percent increase</a></span></li></ul></li><li><span><a href="#Decomposition---Study-Trend,-Seasonality,-and-Stationarity" data-toc-modified-id="Decomposition---Study-Trend,-Seasonality,-and-Stationarity-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Decomposition - Study Trend, Seasonality, and Stationarity</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Trend-and-Seasonality" data-toc-modified-id="Trend-and-Seasonality-5.0.1"><span class="toc-item-num">5.0.1&nbsp;&nbsp;</span>Trend and Seasonality</a></span></li></ul></li><li><span><a href="#Add-Stationarity-Check" data-toc-modified-id="Add-Stationarity-Check-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Add Stationarity Check</a></span><ul class="toc-item"><li><span><a href="#Dickey-Fuler-Results" data-toc-modified-id="Dickey-Fuler-Results-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Dickey-Fuler Results</a></span></li></ul></li></ul></li><li><span><a href="#Step-5:-SARIMA-Modeling" data-toc-modified-id="Step-5:-SARIMA-Modeling-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Step 5: SARIMA Modeling</a></span><ul class="toc-item"><li><span><a href="#Train,-Test,-Split" data-toc-modified-id="Train,-Test,-Split-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Train, Test, Split</a></span></li><li><span><a href="#Grid-Search-Params-for-SARIMA-Model" data-toc-modified-id="Grid-Search-Params-for-SARIMA-Model-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Grid Search Params for SARIMA Model</a></span></li><li><span><a href="#Parameter-Selection-for-the-ARIMA-Time-Series-Model" data-toc-modified-id="Parameter-Selection-for-the-ARIMA-Time-Series-Model-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Parameter Selection for the ARIMA Time Series Model</a></span></li></ul></li><li><span><a href="#Step-6:-Interpreting-Results" data-toc-modified-id="Step-6:-Interpreting-Results-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Step 6: Interpreting Results</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Dynamic-Forecasting" data-toc-modified-id="Dynamic-Forecasting-7.0.1"><span class="toc-item-num">7.0.1&nbsp;&nbsp;</span>Dynamic Forecasting</a></span></li></ul></li><li><span><a href="#Calculate-RMSE" data-toc-modified-id="Calculate-RMSE-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Calculate RMSE</a></span></li><li><span><a href="#Producing-and-Visualizing-Forecasts" data-toc-modified-id="Producing-and-Visualizing-Forecasts-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Producing and Visualizing Forecasts</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Data Exploration

# %%
# Import necessary libraries
import warnings
warnings.filterwarnings('ignore')
import itertools
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
plt.style.use('ggplot')
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('zillow_data.csv')
df.head(10)
# Out:
#    RegionID  RegionName           City State              Metro  \
# 0     84654       60657        Chicago    IL            Chicago
# 1     90668       75070       McKinney    TX  Dallas-Fort Worth
# 2     91982       77494           Katy    TX            Houston
# 3     84616       60614        Chicago    IL            Chicago
# 4     93144       79936        El Paso    TX            El Paso
# 5     91733       77084        Houston    TX            Houston
# 6     61807       10467       New York    NY           New York
# 7     84640       60640        Chicago    IL            Chicago
# 8     91940       77449           Katy    TX            Houston
# 9     97564       94109  San Francisco    CA      San Francisco
#
#       CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-07  \
# 0           Cook         1  334200.0  335400.0  336500.0  ...  1005500
# 1         Collin         2  235700.0  236900.0  236700.0  ...   308000
# ...

# %%
df8 = df['State']
df8_ls = []
df8_ls.append(df8.value_counts())
print(len(df8.value_counts()))
print(df8.value_counts())
# Out:
# 51
# CA    1224
# NY    1015
# TX     989
# PA     831
# FL     785
# OH     588
# IL     547
# NJ     502
# MI     499
# IN     428
# NC     428
# MA     417
# TN     404
# VA     401
# MN     375
# GA     345
# WA     341
# WI     332
# MO     319
# MD     317
# CO     249
# KS     241
# AZ     230
# OR     224
# OK     221
# SC     206
# NH     199
# LA     193
# AL     183
# IA     158
# MS     153
# KY     139
# CT     124
# UT     121
# ID     110
# AR     105
# NV     103
# ME      86
# NE      83
# WV      72
# MT      71
# HI      62
# NM      60
# RI      59
# DE      41
# ND      31
# WY      31
# AK      28
# SD      19
# DC      18
# VT      16
# Name: State, dtype: int64

# %% [markdown]
# ## Raw Difference and Percent Change of median house prices from April 2013 to April 2018
# * I chose to use the final five years of the data set to optimize for recent trends, and because 5 years is a more optimal investment horizon than 20 years.
#
# * I wonder if I should be using data from post 2009 real estate crash?
#     * Maybe experiment with modeling price change from 2011/2012?

# %%
# make copy of df
df1 = df.copy()

# add column with difference between 2017 and 1996 average value
df1['Raw Difference'] = df['2018-04'] - df['2012-04']

# add column with percent change between 2017 and 1996 average value
df1['Percent Change'] = (df['2018-04'] / df['2012-04']) * 100

df1.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-09  2017-10  2017-11  \
# 0         1  334200.0  335400.0  336500.0  ...  1007800  1009600  1013300
# 1         2  235700.0  236900.0  236700.0  ...   312500   314100   315000
# 2         3  210400.0  212200.0  212200.0  ...   320200   320400   320800
# 3         4  498100.0  500900.0  503100.0  ...  1287400  1291500  1296600
# 4         5   77300.0   77300.0   77300.0  ...   120000   120300   120300
#
#    2017-12  2018-01  2018-02  2018-03  2018-04  Raw Difference  Percent Change
# ...

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Set index as Zip Code

# %%
# Rename RegionName as ZipCode
df1 = df1.rename(columns={"RegionName": "ZipCode"})

# Set Index as ZipCode
# df1.set_index('ZipCode', inplace=True)

df1.head()
# Out:
#    RegionID  ZipCode      City State              Metro CountyName  SizeRank  \
# 0     84654    60657   Chicago    IL            Chicago       Cook         1
# 1     90668    75070  McKinney    TX  Dallas-Fort Worth     Collin         2
# 2     91982    77494      Katy    TX            Houston     Harris         3
# 3     84616    60614   Chicago    IL            Chicago       Cook         4
# 4     93144    79936   El Paso    TX            El Paso    El Paso         5
#
#     1996-04   1996-05   1996-06  ...  2017-09  2017-10  2017-11  2017-12  \
# 0  334200.0  335400.0  336500.0  ...  1007800  1009600  1013300  1018700
# 1  235700.0  236900.0  236700.0  ...   312500   314100   315000   316600
# 2  210400.0  212200.0  212200.0  ...   320200   320400   320800   321200
# 3  498100.0  500900.0  503100.0  ...  1287400  1291500  1296600  1299000
# 4   77300.0   77300.0   77300.0  ...   120000   120300   120300   120300
#
# ...

# %%
# create new dataframe with top 10 zip codes for Raw Increase and 
# top ten zip codes for Percent Change

df_raw = df1.sort_values('Raw Difference',ascending = False)
print('Raw Difference:\n',df_raw.head(10))

print()

df_percent = df1.sort_values('Percent Change',ascending = False)
print('Percent Change:\n',df_percent.head(10))
# Out:
# Raw Difference:
#         RegionID  ZipCode           City State                           Metro  \
# 272       61635    10021       New York    NY                        New York
# 10237     97518    94027       Atherton    CA                   San Francisco
# 20        61625    10011       New York    NY                        New York
# 4816      96086    90210  Beverly Hills    CA  Los Angeles-Long Beach-Anaheim
# 5738      97691    94301      Palo Alto    CA                        San Jose
# 5843      97513    94022      Los Altos    CA                        San Jose
# 2026      97577    94123  San Francisco    CA                   San Francisco
# 4723      72636    33480     Palm Beach    FL           Miami-Fort Lauderdale
# 1534      62028    11217       New York    NY                        New York
# 508       61628    10014       New York    NY                        New York
#
#           CountyName  SizeRank    1996-04    1996-05    1996-06  ...  \
# ...

# %% [markdown]
# ## New df's for top 10 raw and percent increase by median house price

# %%
# new df_raw with only top ten results
df_raw = df_raw.head(10)
df_raw
# Out:
#        RegionID  ZipCode           City State                           Metro  \
# 272       61635    10021       New York    NY                        New York
# 10237     97518    94027       Atherton    CA                   San Francisco
# 20        61625    10011       New York    NY                        New York
# 4816      96086    90210  Beverly Hills    CA  Los Angeles-Long Beach-Anaheim
# 5738      97691    94301      Palo Alto    CA                        San Jose
# 5843      97513    94022      Los Altos    CA                        San Jose
# 2026      97577    94123  San Francisco    CA                   San Francisco
# 4723      72636    33480     Palm Beach    FL           Miami-Fort Lauderdale
# 1534      62028    11217       New York    NY                        New York
# 508       61628    10014       New York    NY                        New York
#
#           CountyName  SizeRank    1996-04    1996-05    1996-06  ...  \
# ...

# %%
# new df_percent with only top ten results
df_percent = df_percent.head(10)
df_percent
# Out:
#       RegionID  ZipCode           City State                  Metro  \
# 1946     94751    85035        Phoenix    AZ                Phoenix
# 1477     97803    94601        Oakland    CA          San Francisco
# 1239     97795    94590        Vallejo    CA                Vallejo
# 2627     72619    33460     Lake Worth    FL  Miami-Fort Lauderdale
# 1681     97808    94606        Oakland    CA          San Francisco
# 1853     97850    94804       Richmond    CA          San Francisco
# 1960     95800    89104      Las Vegas    NV              Las Vegas
# 474      94724    85008        Phoenix    AZ                Phoenix
# 4298     98433    95824     Sacramento    CA             Sacramento
# 2409     72571    33404  Riviera Beach    FL  Miami-Fort Lauderdale
#
#         CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-09  \
# 1946      Maricopa      1947       NaN       NaN       NaN  ...   150800
# ...

# %% [markdown]
# ## No duplicates in top 10 zip codes by raw and percent increase.

# %% [markdown]
# ## Concatenate raw and percent df's

# %%
prospects = pd.concat([df_percent,df_raw])
prospects
# Out:
#        RegionID  ZipCode           City State                           Metro  \
# 1946      94751    85035        Phoenix    AZ                         Phoenix
# 1477      97803    94601        Oakland    CA                   San Francisco
# 1239      97795    94590        Vallejo    CA                         Vallejo
# 2627      72619    33460     Lake Worth    FL           Miami-Fort Lauderdale
# 1681      97808    94606        Oakland    CA                   San Francisco
# 1853      97850    94804       Richmond    CA                   San Francisco
# 1960      95800    89104      Las Vegas    NV                       Las Vegas
# 474       94724    85008        Phoenix    AZ                         Phoenix
# 4298      98433    95824     Sacramento    CA                      Sacramento
# 2409      72571    33404  Riviera Beach    FL           Miami-Fort Lauderdale
# 272       61635    10021       New York    NY                        New York
# ...

# %%
# Remove Raw Difference and Percent Change for melting
prospects = prospects.drop(columns=['Raw Difference', 'Percent Change', 'RegionID'])
prospects
# Out:
#        ZipCode           City State                           Metro  \
# 1946     85035        Phoenix    AZ                         Phoenix
# 1477     94601        Oakland    CA                   San Francisco
# 1239     94590        Vallejo    CA                         Vallejo
# 2627     33460     Lake Worth    FL           Miami-Fort Lauderdale
# 1681     94606        Oakland    CA                   San Francisco
# 1853     94804       Richmond    CA                   San Francisco
# 1960     89104      Las Vegas    NV                       Las Vegas
# 474      85008        Phoenix    AZ                         Phoenix
# 4298     95824     Sacramento    CA                      Sacramento
# 2409     33404  Riviera Beach    FL           Miami-Fort Lauderdale
# 272      10021       New York    NY                        New York
# 10237    94027       Atherton    CA                   San Francisco
# 20       10011       New York    NY                        New York
# ...

# %% [markdown]
# ## Check for missing data

# %%
prospects.isnull().values.any()
# Out:
# True

# %%
print(prospects.isnull().sum().sum())
# Out:
# 555

# %% [markdown]
# ## There is a large amount of missing data in 5 columns
# * Leaving the missing data is OK as it will be removed in the melt_data function
# * Due to the predictive nature of this model, I want to remove those rows, as there will still be 15 zip codes to explore.
# * Sadly, this will exclude the New York region, which had some of the higher raw increases.

# %%
# drop from original index
# prospects = prospects.drop([508, 1534, 20, 272, 1946])

# drop from ZipCode index
#prospects = prospects.drop([10014, 11217, 10011, 10021, 85035])
#prospects

# %%
print(prospects.isnull().sum().sum())
# Out:
# 555

# %% [markdown]
# ## Final 20 Zip Codes

# %%
prospects
# Out:
#        ZipCode           City State                           Metro  \
# 1946     85035        Phoenix    AZ                         Phoenix
# 1477     94601        Oakland    CA                   San Francisco
# 1239     94590        Vallejo    CA                         Vallejo
# 2627     33460     Lake Worth    FL           Miami-Fort Lauderdale
# 1681     94606        Oakland    CA                   San Francisco
# 1853     94804       Richmond    CA                   San Francisco
# 1960     89104      Las Vegas    NV                       Las Vegas
# 474      85008        Phoenix    AZ                         Phoenix
# 4298     95824     Sacramento    CA                      Sacramento
# 2409     33404  Riviera Beach    FL           Miami-Fort Lauderdale
# 272      10021       New York    NY                        New York
# 10237    94027       Atherton    CA                   San Francisco
# 20       10011       New York    NY                        New York
# ...

# %% [markdown]
# ### Option to include missing data
# * Missing data can be included as it will be removed in the melt_data function

# %% [markdown]
# # Step 3: Exporatory Data Analysis and Visualization

# %% [markdown]
# ## Melt and plot Median Price for Top 20 Zip Codes

# %% [markdown]
# ### Add melt_data function to melt data for visualization

# %%
def melt_data(df):
    """
    Takes the zillow_data dataset in wide form or a subset of the zillow_dataset.  
    Returns a long-form datetime dataframe 
    with the datetime column names as the index and the values as the 'values' column.
    
    If more than one row is passes in the wide-form dataset, the values column
    will be the mean of the values from the datetime columns in all of the rows.
    """
    
    melted = pd.melt(df, id_vars=['ZipCode','SizeRank', 'City', 'State', 'Metro', 'CountyName'], var_name='time')
    melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)
    melted = melted.dropna(subset=['value'])
    return melted.groupby('time').aggregate({'value':'mean'})

# %% [markdown]
# ### Practicing with .melt function

# %%
# prospects['ZipCode']

# %%
# mm

# %%
# Practicing with melt function

#mm = pd.melt(prospects, id_vars=['SizeRank', 'City', 'State', 'Metro', 'CountyName'], var_name='time')
#mm['time'] = pd.to_datetime(mm['time'], infer_datetime_format=True)
#mm = mm.dropna(subset=['value'])
#mm = mm.groupby('time')
#mm.ngroups

# %%
#mm.size()

# %%
#mm.last()

# %%
# print median price for each zipcode on same plot
#initial = melt_data(prospects[prospects['ZipCode'] == 94601])

#for zipcode in prospects['ZipCode']:
#    dataframe = prospects.loc[prospects['ZipCode'] == zipcode]
#    melted = melt_data(dataframe)
#    melted_together = pd.concat([melted, initial], join='left')
#    melted_together
    ## df.loc[df['column_name'] == some_value]

# %%
#print(melted_together)

# %% [markdown]
# ### Concatenate melted zips

# %%
prospects
# Out:
#        ZipCode           City State                           Metro  \
# 1946     85035        Phoenix    AZ                         Phoenix
# 1477     94601        Oakland    CA                   San Francisco
# 1239     94590        Vallejo    CA                         Vallejo
# 2627     33460     Lake Worth    FL           Miami-Fort Lauderdale
# 1681     94606        Oakland    CA                   San Francisco
# 1853     94804       Richmond    CA                   San Francisco
# 1960     89104      Las Vegas    NV                       Las Vegas
# 474      85008        Phoenix    AZ                         Phoenix
# 4298     95824     Sacramento    CA                      Sacramento
# 2409     33404  Riviera Beach    FL           Miami-Fort Lauderdale
# 272      10021       New York    NY                        New York
# 10237    94027       Atherton    CA                   San Francisco
# 20       10011       New York    NY                        New York
# ...

# %%
# Create new df by melting prospects df by zip code

m2 = pd.DataFrame()

for zipcode in prospects['ZipCode']:
    zips = prospects.loc[prospects['ZipCode'] == zipcode]
    m1 = melt_data(zips)
    m1[zips.iloc[0,1],zips.iloc[0,2],str(zipcode)] = m1['value']
    m1 = m1.drop('value', axis=1)
    m2 = pd.concat([m1,m2], axis=1)
    m2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 94 entries, 2010-07-01 to 2018-04-01
# Data columns (total 1 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   (Phoenix, AZ, 85035)  94 non-null     float64
# dtypes: float64(1)
# memory usage: 1.5 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Freq: MS
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   (Oakland, CA, 94601)  265 non-null    float64
#  1   (Phoenix, AZ, 85035)  94 non-null     float64
# dtypes: float64(2)
# memory usage: 6.2 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
# ...

# %%
m2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Freq: MS
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   (New York, NY, 10014)       172 non-null    float64
#  1   (New York, NY, 11217)       172 non-null    float64
#  2   (Palm Beach, FL, 33480)     265 non-null    float64
#  3   (San Francisco, CA, 94123)  265 non-null    float64
#  4   (Los Altos, CA, 94022)      265 non-null    float64
#  5   (Palo Alto, CA, 94301)      265 non-null    float64
#  6   (Beverly Hills, CA, 90210)  265 non-null    float64
#  7   (New York, NY, 10011)       160 non-null    float64
#  8   (Atherton, CA, 94027)       265 non-null    float64
#  9   (New York, NY, 10021)       172 non-null    float64
#  10  (Riviera Beach, FL, 33404)  265 non-null    float64
#  11  (Sacramento, CA, 95824)     265 non-null    float64
# ...

# %% [markdown]
# ### Plot median house price by date for 20 zip codes
# * Plot on same chart

# %%
m2.plot(figsize=(15, 10))
plt.xlabel('Year', fontsize=20)
plt.ylabel('House Price (million $)', fontsize=20);
plt.title('Median House Price')
plt.show()

# %% [markdown]
# ## Plot Top 10 Percent Return zip code charts
# * Tried dropping columns from m1, but can't due to spaces in titles
#     * The spaces do help with interpretation, so I'll use an older df and re-melt/concatenate

# %%
low_val = df_percent
low_val
# Out:
#       RegionID  ZipCode           City State                  Metro  \
# 1946     94751    85035        Phoenix    AZ                Phoenix
# 1477     97803    94601        Oakland    CA          San Francisco
# 1239     97795    94590        Vallejo    CA                Vallejo
# 2627     72619    33460     Lake Worth    FL  Miami-Fort Lauderdale
# 1681     97808    94606        Oakland    CA          San Francisco
# 1853     97850    94804       Richmond    CA          San Francisco
# 1960     95800    89104      Las Vegas    NV              Las Vegas
# 474      94724    85008        Phoenix    AZ                Phoenix
# 4298     98433    95824     Sacramento    CA             Sacramento
# 2409     72571    33404  Riviera Beach    FL  Miami-Fort Lauderdale
#
#         CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-09  \
# 1946      Maricopa      1947       NaN       NaN       NaN  ...   150800
# ...

# %%
# Remove Raw Difference and Percent Change for melting
low_val = low_val.drop(columns=['Raw Difference', 'Percent Change', 'RegionID'])

# %%
m2 = pd.DataFrame()

for zipcode in low_val['ZipCode']:
    zips = low_val.loc[low_val['ZipCode'] == zipcode]
    m1 = melt_data(zips)
    m1[zips.iloc[0,1],zips.iloc[0,2],str(zipcode)] = m1['value']
    m1 = m1.drop('value', axis=1)
    m2 = pd.concat([m1,m2], axis=1)
    m2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 94 entries, 2010-07-01 to 2018-04-01
# Data columns (total 1 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   (Phoenix, AZ, 85035)  94 non-null     float64
# dtypes: float64(1)
# memory usage: 1.5 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Freq: MS
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   (Oakland, CA, 94601)  265 non-null    float64
#  1   (Phoenix, AZ, 85035)  94 non-null     float64
# dtypes: float64(2)
# memory usage: 6.2 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
# ...

# %% [markdown]
# ### Plot Median value of Low-Value housing by zip code

# %%
m2
# Out:
#             (Riviera Beach, FL, 33404)  (Sacramento, CA, 95824)  \
# time
# 1996-04-01                     56800.0                  73800.0
# 1996-05-01                     56700.0                  73400.0
# 1996-06-01                     56600.0                  73000.0
# 1996-07-01                     56500.0                  72600.0
# 1996-08-01                     56500.0                  72200.0
# ...                                ...                      ...
# 2017-12-01                    128500.0                 218400.0
# 2018-01-01                    129900.0                 221400.0
# 2018-02-01                    130700.0                 223500.0
# 2018-03-01                    132300.0                 224700.0
# 2018-04-01                    134700.0                 224700.0
#
#             (Phoenix, AZ, 85008)  (Las Vegas, NV, 89104)  \
# time
# 1996-04-01               61600.0                 94800.0
# 1996-05-01               61900.0                 94700.0
# ...

# %%
m2.plot(figsize=(15, 10))
plt.xlabel('Year', fontsize=20)
plt.ylabel('House Price (million $)', fontsize=20);
plt.title('Low-Value Zip Codes - Median House Price')
plt.show()

# %% [markdown]
# ## Plot Top 10 Raw Price Increase zip code charts
# * Tried dropping columns from m1, but can't due to spaces in titles
#     * The spaces do help with interpretation, so I'll use an older df and re-melt/concatenate

# %%
high_val = df_raw
high_val
# Out:
#        RegionID  ZipCode           City State                           Metro  \
# 272       61635    10021       New York    NY                        New York
# 10237     97518    94027       Atherton    CA                   San Francisco
# 20        61625    10011       New York    NY                        New York
# 4816      96086    90210  Beverly Hills    CA  Los Angeles-Long Beach-Anaheim
# 5738      97691    94301      Palo Alto    CA                        San Jose
# 5843      97513    94022      Los Altos    CA                        San Jose
# 2026      97577    94123  San Francisco    CA                   San Francisco
# 4723      72636    33480     Palm Beach    FL           Miami-Fort Lauderdale
# 1534      62028    11217       New York    NY                        New York
# 508       61628    10014       New York    NY                        New York
#
#           CountyName  SizeRank    1996-04    1996-05    1996-06  ...  \
# ...

# %%
# Remove Raw Difference and Percent Change for melting
high_val = high_val.drop(columns=['Raw Difference', 'Percent Change', 'RegionID'])

# %%
m3 = pd.DataFrame()

for zipcode in high_val['ZipCode']:
    zips = high_val.loc[high_val['ZipCode'] == zipcode]
    m1 = melt_data(zips)
    m1[zips.iloc[0,1],zips.iloc[0,2],str(zipcode)] = m1['value']
    m1 = m1.drop('value', axis=1)
    m3 = pd.concat([m1,m3], axis=1)
    m3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 172 entries, 2004-01-01 to 2018-04-01
# Data columns (total 1 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (New York, NY, 10021)  172 non-null    float64
# dtypes: float64(1)
# memory usage: 2.7 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Freq: MS
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Atherton, CA, 94027)  265 non-null    float64
#  1   (New York, NY, 10021)  172 non-null    float64
# dtypes: float64(2)
# memory usage: 6.2 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Freq: MS
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
# ...

# %% [markdown]
# ### Plot Median value of Low-Value housing by zip code

# %%
m3.plot(figsize=(15, 8))
plt.xlabel('Year', fontsize=20)
plt.ylabel('House Price (million $)', fontsize=20);
plt.title('High Value ZipCodes - Median House Price')
plt.show()

# %% [markdown]
# # Select individual zip codes, build new dataframes

# %% [markdown]
# ## Top New York and California zips by raw increase

# %%
raw1 = high_val.loc[high_val['ZipCode'] == 10021]
raw1 = melt_data(raw1)
raw1['10021'] = raw1['value']
raw1 = raw1.drop('value', axis=1)
raw1 = raw1.dropna(axis=0)
raw1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 172 entries, 2004-01-01 to 2018-04-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   10021   172 non-null    float64
# dtypes: float64(1)
# memory usage: 2.7 KB

# %%
raw2 = high_val.loc[high_val['ZipCode'] == 94027]
raw2 = melt_data(raw2)
raw2['94027'] = raw2['value']
raw2 = raw2.drop('value', axis=1)
raw2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   94027   265 non-null    float64
# dtypes: float64(1)
# memory usage: 4.1 KB

# %% [markdown]
# ## Top zips by percent increase

# %%
percent1 = low_val.loc[low_val['ZipCode'] == 94606]
percent1 = melt_data(percent1)
percent1['94606'] = percent1['value']
percent1 = percent1.drop('value', axis=1)
percent1 = percent1.dropna(axis=0)
percent1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   94606   265 non-null    float64
# dtypes: float64(1)
# memory usage: 4.1 KB

# %%
percent2 = low_val.loc[low_val['ZipCode'] == 95824]
percent2 = melt_data(percent2)
percent2['95824'] = percent2['value']
percent2 = percent2.drop('value', axis=1)
percent2 = percent2.dropna(axis=0)
percent2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   95824   265 non-null    float64
# dtypes: float64(1)
# memory usage: 4.1 KB

# %% [markdown]
# # Decomposition - Study Trend, Seasonality, and Stationarity

# %%
percent1
# Out:
#                94606
# time
# 1996-04-01  120400.0
# 1996-05-01  120300.0
# 1996-06-01  120300.0
# 1996-07-01  120200.0
# 1996-08-01  120100.0
# ...              ...
# 2017-12-01  663100.0
# 2018-01-01  676500.0
# 2018-02-01  683700.0
# 2018-03-01  691700.0
# 2018-04-01  696800.0
#
# [265 rows x 1 columns]

# %%
# Import and apply seasonal_decompose()
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(np.log(percent1))

# Gather the trend, seasonality, and residuals 
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Plot gathered statistics
plt.figure(figsize=(12,8))
plt.subplot(411)
plt.plot(np.log(m1), label='Original', color='blue')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend', color='blue')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality', color='blue')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals', color='blue')
plt.legend(loc='best')
plt.tight_layout()

# %%
# trying to interpret magnitude of seasonal trend
np.exp(.001)
# Out:
# 1.0010005001667084

# %% [markdown]
# ### Trend and Seasonality
# * The trend fluctuates on this time scale, with price increasing until 2007, then decreasing until 2011, then increasing again after 2011.
# * Seasonality is observed in housing prices, but the seasonality does not have enough magnitude to be observed in the raw values, so the decomposition was helpful in illuminating this aspect of the data.

# %% [markdown]
# ## Add Stationarity Check

# %%
def stationarity_check(TS):
    
    # Import adfuller
    from statsmodels.tsa.stattools import adfuller
    
    # Calculate rolling statistics
    roll_mean = TS.rolling(window=8, center=False).mean()
    roll_std = TS.rolling(window=8, center=False).std()
    
    # Perform the Dickey Fuller test
    dftest = adfuller(TS) 
    
    # Plot rolling statistics:
    fig = plt.figure(figsize=(12,6))
    orig = plt.plot(TS, color='blue',label='Original')
    mean = plt.plot(roll_mean, color='red', label='Rolling Mean')
    std = plt.plot(roll_std, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    # Print Dickey-Fuller test results
    print('Results of Dickey-Fuller Test: \n')

    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', 
                                             '#Lags Used', 'Number of Observations Used'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
    
    return None

# %%
# Drop missing values from residuals 
percent1_log_decompose = residual
percent1_log_decompose.dropna(inplace=True)

# Check stationarity
stationarity_check(percent1_log_decompose)
# Out:
# Results of Dickey-Fuller Test:
#
# Test Statistic                  -4.361429
# p-value                          0.000347
# #Lags Used                      14.000000
# Number of Observations Used    238.000000
# Critical Value (1%)             -3.458128
# Critical Value (5%)             -2.873762
# Critical Value (10%)            -2.573283
# dtype: float64

# %% [markdown]
# ### Dickey-Fuler Results
# * Considering the p-value is well below 0.05, this model is stationary.

# %% [markdown]
# # Step 5: SARIMA Modeling

# %% [markdown]
# ## Train, Test, Split
# * Test model accuracy later

# %%
percent1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   94606   265 non-null    float64
# dtypes: float64(1)
# memory usage: 4.1 KB

# %%
percent1.iloc[238:]
# Out:
#                94606
# time
# 2016-02-01  481900.0
# 2016-03-01  488000.0
# 2016-04-01  494100.0
# 2016-05-01  499600.0
# 2016-06-01  502900.0
# 2016-07-01  508000.0
# 2016-08-01  515200.0
# 2016-09-01  521200.0
# 2016-10-01  525600.0
# 2016-11-01  530700.0
# 2016-12-01  536900.0
# 2017-01-01  546900.0
# 2017-02-01  558600.0
# 2017-03-01  565600.0
# 2017-04-01  571000.0
# 2017-05-01  578700.0
# 2017-06-01  588600.0
# 2017-07-01  599200.0
# 2017-08-01  611000.0
# 2017-09-01  622300.0
# 2017-10-01  632800.0
# 2017-11-01  646100.0
# 2017-12-01  663100.0
# 2018-01-01  676500.0
# 2018-02-01  683700.0
# 2018-03-01  691700.0
# 2018-04-01  696800.0

# %%
train = percent1.iloc[:238]
test = percent1.iloc[238:]

# %%
train
# Out:
#                94606
# time
# 1996-04-01  120400.0
# 1996-05-01  120300.0
# 1996-06-01  120300.0
# 1996-07-01  120200.0
# 1996-08-01  120100.0
# ...              ...
# 2015-09-01  455000.0
# 2015-10-01  460600.0
# 2015-11-01  465400.0
# 2015-12-01  470800.0
# 2016-01-01  476900.0
#
# [238 rows x 1 columns]

# %%
test
# Out:
#                94606
# time
# 2016-02-01  481900.0
# 2016-03-01  488000.0
# 2016-04-01  494100.0
# 2016-05-01  499600.0
# 2016-06-01  502900.0
# 2016-07-01  508000.0
# 2016-08-01  515200.0
# 2016-09-01  521200.0
# 2016-10-01  525600.0
# 2016-11-01  530700.0
# 2016-12-01  536900.0
# 2017-01-01  546900.0
# 2017-02-01  558600.0
# 2017-03-01  565600.0
# 2017-04-01  571000.0
# 2017-05-01  578700.0
# 2017-06-01  588600.0
# 2017-07-01  599200.0
# 2017-08-01  611000.0
# 2017-09-01  622300.0
# 2017-10-01  632800.0
# 2017-11-01  646100.0
# 2017-12-01  663100.0
# 2018-01-01  676500.0
# 2018-02-01  683700.0
# 2018-03-01  691700.0
# 2018-04-01  696800.0

# %% [markdown]
# ## Grid Search Params for SARIMA Model
# * Too computationally expensive for my computer (>15 minutes)
# * Different function in step 5.2

# %%
m1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 172 entries, 2004-01-01 to 2018-04-01
# Data columns (total 1 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (New York, NY, 10014)  172 non-null    float64
# dtypes: float64(1)
# memory usage: 7.7 KB

# %% [raw]
# # grid search sarima hyperparameters for daily female dataset
# from math import sqrt
# from multiprocessing import cpu_count
# from joblib import Parallel
# from joblib import delayed
# from warnings import catch_warnings
# from warnings import filterwarnings
# from statsmodels.tsa.statespace.sarimax import SARIMAX
# from sklearn.metrics import mean_squared_error
# from pandas import read_csv
#
# # one-step sarima forecast
# def sarima_forecast(history, config):
# 	order, sorder, trend = config
# 	# define model
# 	model = SARIMAX(history, order=order, seasonal_order=sorder, trend=trend, enforce_stationarity=False, enforce_invertibility=False)
# 	# fit model
# 	model_fit = model.fit(disp=False)
# 	# make one step forecast
# 	yhat = model_fit.predict(len(history), len(history))
# 	return yhat[0]
#
# # root mean squared error or rmse
# def measure_rmse(actual, predicted):
# 	return sqrt(mean_squared_error(actual, predicted))
#
# # split a univariate dataset into train/test sets
# def train_test_split(data, n_test):
# 	return data[:-n_test], data[-n_test:]
#
# # walk-forward validation for univariate data
# def walk_forward_validation(data, n_test, cfg):
# 	predictions = list()
# 	# split dataset
# 	train, test = train_test_split(data, n_test)
# 	# seed history with training dataset
# 	history = [x for x in train]
# 	# step over each time-step in the test set
# 	for i in range(len(test)):
# 		# fit model and make forecast for history
# 		yhat = sarima_forecast(history, cfg)
# 		# store forecast in list of predictions
# 		predictions.append(yhat)
# 		# add actual observation to history for the next loop
# 		history.append(test[i])
# 	# estimate prediction error
# 	error = measure_rmse(test, predictions)
# 	return error
#
# # score a model, return None on failure
# def score_model(data, n_test, cfg, debug=False):
# 	result = None
# 	# convert config to a key
# 	key = str(cfg)
# 	# show all warnings and fail on exception if debugging
# 	if debug:
# 		result = walk_forward_validation(data, n_test, cfg)
# 	else:
# 		# one failure during model validation suggests an unstable config
# 		try:
# 			# never show warnings when grid searching, too noisy
# 			with catch_warnings():
# 				filterwarnings("ignore")
# 				result = walk_forward_validation(data, n_test, cfg)
# 		except:
# 			error = None
# 	# check for an interesting result
# 	if result is not None:
# 		print(' > Model[%s] %.3f' % (key, result))
# 	return (key, result)
#
# # grid search configs
# def grid_search(data, cfg_list, n_test, parallel=True):
# 	scores = None
# 	if parallel:
# 		# execute configs in parallel
# 		executor = Parallel(n_jobs=cpu_count(), backend='multiprocessing')
# 		tasks = (delayed(score_model)(data, n_test, cfg) for cfg in cfg_list)
# 		scores = executor(tasks)
# 	else:
# 		scores = [score_model(data, n_test, cfg) for cfg in cfg_list]
# 	# remove empty results
# 	scores = [r for r in scores if r[1] != None]
# 	# sort configs by error, asc
# 	scores.sort(key=lambda tup: tup[1])
# 	return scores
#
# # create a set of sarima configs to try
# def sarima_configs(seasonal=[0]):
# 	models = list()
# 	# define config lists
# 	p_params = [0, 1, 2]
# 	d_params = [0, 1]
# 	q_params = [0, 1, 2]
# 	t_params = ['n','c','t','ct']
# 	P_params = [0, 1, 2]
# 	D_params = [0, 1]
# 	Q_params = [0, 1, 2]
# 	m_params = seasonal
# 	# create config instances
# 	for p in p_params:
# 		for d in d_params:
# 			for q in q_params:
# 				for t in t_params:
# 					for P in P_params:
# 						for D in D_params:
# 							for Q in Q_params:
# 								for m in m_params:
# 									cfg = [(p,d,q), (P,D,Q,m), t]
# 									models.append(cfg)
# 	return models
#
# if __name__ == '__main__':
# 	# load dataset
# 	series = m1
# 	data = series.values
# 	print(data.shape)
# 	# data split
# 	n_test = 238
# 	# model configs
# 	cfg_list = sarima_configs()
# 	# grid search
# 	scores = grid_search(data, cfg_list, n_test)
# 	print('done')
# 	# list top 3 configs
# 	for cfg, error in scores[:3]:
# 		print(cfg, error)

# %% [markdown]
# ## Parameter Selection for the ARIMA Time Series Model
#
# The first step towards fitting an ARIMA model is to find the values of `ARIMA(p,d,q)(P,D,Q)s` that produce the desired output. Selection of these parameters requires domain expertise and time.  We shall first generate small ranges of these parameters and use a "grid search" to iteratively explore different combinations of parameters. For each combination of parameters, we fit a new seasonal ARIMA model with the `SARIMAX()` function from the `statsmodels` library and assess its overall quality.
#
# `SARIMAX` detailed documentation can be viewed [here](https://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.sarimax.SARIMAX.html)
#
# Let's begin by generating example combination of parameters that we wish to use:
#
# - Define p, q, and d parameters to take any value from 0/1 using `range()` function. (Note: We can try larger values which can make our model computationally expensive to run, you can try this as an additional experiment)
# - Generate combinations for `(p,d,q)` using `itertools.product`
# - Similarly, generate seasonal combinations as `(p,d,q)s`. Use s = 12 (constant)
# - Print some example combinations for seasonal ARIMA

# %%
# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
pdqs = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %%
pdqs
# Out:
# [(0, 0, 0, 12),
#  (0, 0, 1, 12),
#  (0, 1, 0, 12),
#  (0, 1, 1, 12),
#  (1, 0, 0, 12),
#  (1, 0, 1, 12),
#  (1, 1, 0, 12),
#  (1, 1, 1, 12)]

# %%
# Run a grid with pdq and seasonal pdq parameters calculated above and get the best AIC value
ans = []
outputs = []
comb_list = []
combs_list = []

for comb in pdq:
    for combs in pdqs:
        try:
            mod = sm.tsa.statespace.SARIMAX(train,
                                            order=comb,
                                            seasonal_order=combs,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            output = mod.fit()
            ans.append([comb, combs, output.aic])
            outputs.append([output.aic])
            comb_list.append([comb])
            combs_list.append([combs])
            AIC_df = pd.DataFrame(list(zip(outputs, comb_list, combs_list)))
            #print('ARIMA {} x {}12 : AIC Calculated ={}'.format(comb, combs, output.aic))
        except:
            continue

# Print the lowest AIC and it's parameters for SARIMA
AIC_df[0] = AIC_df[0].str.get(0)
best_AIC = AIC_df.copy()
lowest_AIC = min(best_AIC[0])
lowest_AIC_row = AIC_df.loc[AIC_df[0] == lowest_AIC]
print(lowest_AIC_row)

# call value for comb and combs for model input
lowest_AIC_row[1] = lowest_AIC_row[1].str.get(0)
lowest_AIC_row[2] = lowest_AIC_row[2].str.get(0)
arima = lowest_AIC_row.iat[0,1]
s = lowest_AIC_row.iat[0,2]
print(arima, s)
# Out:
#               0            1                2
# 63  3677.482576  [(1, 1, 1)]  [(1, 1, 1, 12)]
# (1, 1, 1) (1, 1, 1, 12)

# %%
sarima_val = lowest_AIC_row.copy()

# %%
# call value for comb and combs
sarima_val[1] = sarima_val[1].str.get(0)
sarima_val[2] = sarima_val[2].str.get(0)
arima = sarima_val.iat[0,1]
s = sarima_val.iat[0,2]
print(arima, s)
# Out:
# (1, 1, 1) (1, 1, 1, 12)

# %%
AIC_df1 = AIC_df.copy()

# %%
AIC_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       64 non-null     object
#  1   1       64 non-null     object
#  2   2       64 non-null     object
# dtypes: object(3)
# memory usage: 1.6+ KB

# %%
AIC_df[0] = AIC_df[0].str.get(0)
best_AIC = AIC_df.copy()
lowest_AIC = min(best_AIC[0])
lowest_AIC_row = AIC_df.loc[AIC_df[0] == lowest_AIC]
lowest_AIC_row
# Out:
#               0            1                2
# 63  3677.482576  [(1, 1, 1)]  [(1, 1, 1, 12)]

# %%
# Find the parameters with minimal AIC value
ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'aic'])
ans_df.loc[ans_df['aic'].idxmin()]
# Out:
# pdq         (1, 1, 1)
# pdqs    (1, 1, 1, 12)
# aic           3677.48
# Name: 63, dtype: object

# %%
# Plug the optimal parameter values into a new SARIMAX model
ARIMA_MODEL = sm.tsa.statespace.SARIMAX(train, 
                                        order=arima, 
                                        seasonal_order=s, 
                                        enforce_stationarity=False, 
                                        enforce_invertibility=False)

# Fit the model and print results
output = ARIMA_MODEL.fit()

print(output.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8734      0.034     25.839      0.000       0.807       0.940
# ma.L1          0.6692      0.047     14.135      0.000       0.576       0.762
# ar.S.L12       0.2098      0.083      2.515      0.012       0.046       0.373
# ma.S.L12      -0.5293      0.066     -8.053      0.000      -0.658      -0.400
# sigma2      2.408e+06   2.24e+05     10.770      0.000    1.97e+06    2.85e+06
# ...

# %%
# Call plot_diagnostics() on the results calculated above 
output.plot_diagnostics(figsize=(15, 18))
plt.show()

# %% [markdown]
# # Step 6: Interpreting Results

# %%
# Get predictions starting from 01-01-1998 and calculate confidence intervals
pred = output.get_prediction(start=pd.to_datetime('1996-04-01'), dynamic=False)
pred_conf = pred.conf_int()

# %%
pred

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

# Plot observed values
ax = train['1996-04-01':].plot(label='observed')

# Plot predicted values
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=0.9)

# Plot the range for confidence intervals
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='g', alpha=0.5)

# Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Median House Price $')
plt.legend()

plt.show()

# %%
pred.predicted_mean
# Out:
# 1996-04-01         0.000000
# 1996-05-01    155452.476510
# 1996-06-01    114937.593081
# 1996-07-01    120944.522572
# 1996-08-01    120023.493825
#                   ...
# 2015-09-01    453036.853048
# 2015-10-01    465924.110053
# 2015-11-01    462844.011264
# 2015-12-01    470279.972678
# 2016-01-01    477802.056088
# Freq: MS, Name: predicted_mean, Length: 238, dtype: float64

# %%
# Get the real and predicted values
price_forecasted = pred.predicted_mean
price_truth = test['2016-02-01':].value

# Compute the mean square error
mse = ((price_forecasted - price_truth) ** 2).mean()
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))

# %% [markdown]
# ### Dynamic Forecasting
#
# We can achieve a deeper insight into model's predictive power using dynamic forecasts. In this case, we only use information from the time series up to a certain point, and after that, forecasts are generated using values from previous forecasted time points.

# %%
# Get dynamic predictions with confidence intervals as above 
# Use Dynamic forecasting by setting `dynamic` to True.
pred_dynamic = output.get_prediction(start=pd.to_datetime('1996-04-01'), dynamic=True, full_results=True)
pred_dynamic_conf = pred_dynamic.conf_int()

# %%
# Plot the dynamic forecast with confidence intervals as above

# Plot observed values
ax = top_zip_percent_melted['1996-04-01':].plot(label='observed')

# pred_dynamic.predicted_mean.plot(label='Dynamic Forecast', ax=ax)

# ax.fill_between(pred_dynamic_conf.index,
                #pred_dynamic_conf.iloc[:, 0],
                #pred_dynamic_conf.iloc[:, 1], color='g', alpha=.3)

ax.fill_betweenx(ax.get_ylim(), pd.to_datetime('2012-04-01'), price_forecasted.index[-1], alpha=.1, zorder=-1)

ax.set_xlabel('Date')
ax.set_ylabel('Average House Price')

plt.legend()
plt.show()

# %%
# Get forecast 500 steps ahead in future
prediction = output.get_forecast(steps=27)

# Get confidence intervals of forecasts
pred_conf = prediction.conf_int()

# %%
pred_conf
# Out:
#               lower 94606    upper 94606
# 2016-02-01  482187.441139  488269.723869
# 2016-03-01  487724.654193  504342.522746
# 2016-04-01  493922.598733  522834.939557
# 2016-05-01  498215.346330  540471.612423
# 2016-06-01  497639.392974  553849.853295
# 2016-07-01  494823.886463  565309.418316
# 2016-08-01  492389.753625  577272.806939
# 2016-09-01  491949.447083  591213.557400
# 2016-10-01  490023.000076  603553.671497
# 2016-11-01  487675.471813  615289.186834
# 2016-12-01  485437.917512  626903.175625
# 2017-01-01  484165.079865  639217.878498
# 2017-02-01  484415.503493  654426.114473
# 2017-03-01  485871.427747  672905.869396
# 2017-04-01  488015.768554  693522.864127
# 2017-05-01  488543.613500  713473.762436
# 2017-06-01  484753.556941  729676.465738
# 2017-07-01  478948.277990  744151.167958
# 2017-08-01  473291.263163  758855.046321
# 2017-09-01  469363.210845  775219.717742
# 2017-10-01  464266.284363  790240.711491
# 2017-11-01  458862.334140  804704.618342
# ...

# %%
diff = pred_conf.iloc[-1].difference()
diff
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-980e018119ed> in <module>
# ----> 1 diff = pred_conf.iloc[-1].difference()
#       2 diff
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'difference'

# %%
price_truth = test['2016-02-01':]
price_truth['94606']
# Out:
# time
# 2016-02-01    481900.0
# 2016-03-01    488000.0
# 2016-04-01    494100.0
# 2016-05-01    499600.0
# 2016-06-01    502900.0
# 2016-07-01    508000.0
# 2016-08-01    515200.0
# 2016-09-01    521200.0
# 2016-10-01    525600.0
# 2016-11-01    530700.0
# 2016-12-01    536900.0
# 2017-01-01    546900.0
# 2017-02-01    558600.0
# 2017-03-01    565600.0
# 2017-04-01    571000.0
# 2017-05-01    578700.0
# 2017-06-01    588600.0
# 2017-07-01    599200.0
# 2017-08-01    611000.0
# 2017-09-01    622300.0
# 2017-10-01    632800.0
# 2017-11-01    646100.0
# 2017-12-01    663100.0
# 2018-01-01    676500.0
# 2018-02-01    683700.0
# 2018-03-01    691700.0
# 2018-04-01    696800.0
# Name: 94606, dtype: float64

# %%
prediction = output.get_forecast(steps=27)
pred = prediction.predicted_mean
pred[0:]
# Out:
# 2016-02-01    485228.582504
# 2016-03-01    496033.588469
# 2016-04-01    508378.769145
# 2016-05-01    519343.479377
# 2016-06-01    525744.623134
# 2016-07-01    530066.652389
# 2016-08-01    534831.280282
# 2016-09-01    541581.502242
# 2016-10-01    546788.335787
# 2016-11-01    551482.329324
# 2016-12-01    556170.546569
# 2017-01-01    561691.479181
# 2017-02-01    569420.808983
# 2017-03-01    579388.648572
# 2017-04-01    590769.316341
# 2017-05-01    601008.687968
# 2017-06-01    607215.011340
# 2017-07-01    611549.722974
# 2017-08-01    616073.154742
# 2017-09-01    622291.464293
# 2017-10-01    627253.497927
# 2017-11-01    631783.476241
# 2017-12-01    636198.561864
# 2018-01-01    641489.877651
# 2018-02-01    648999.048802
# 2018-03-01    658708.784517
# 2018-04-01    669815.081413
# Freq: MS, Name: predicted_mean, dtype: float64

# %% [markdown]
# ## Calculate RMSE

# %%
# Get actual results in dataframe
price_truth = test['2016-02-01':]

# Get predictions in dataframe
prediction = output.get_forecast(steps=27)
pred = prediction.predicted_mean

# Get the real and predicted values
prediction = pred[0:]
price_truth = price_truth['94606']

# Compute the mean square error
mse = ((prediction - price_truth) ** 2).mean()
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 20070.51

# %%
round(np.sqrt(mse))
# Out:
# 20071.0

# %% [markdown]
# ## Producing and Visualizing Forecasts
#
# We will leverage seasonal ARIMA time series model to forecast future values. The `.get_forecast()` method of the time series output can compute forecasted values for a specified number of steps ahead.

# %%
m1
# Out:
#             (New York, NY, 10014)
# time
# 2004-01-01              5299500.0
# 2004-02-01              4648100.0
# 2004-03-01              4168100.0
# 2004-04-01              3833300.0
# 2004-05-01              3601700.0
# ...                           ...
# 2017-12-01              9492800.0
# 2018-01-01              9524900.0
# 2018-02-01              9373400.0
# 2018-03-01              9119600.0
# 2018-04-01              8959300.0
#
# [172 rows x 1 columns]

# %%
# Plot future predictions with confidence intervals
ax = train.plot(label='observed', figsize=(20, 15))
prediction.pred.plot(ax=ax, label='Forecast')
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='k', alpha=0.25)
ax.set_xlabel('Date')
ax.set_ylabel('House Price')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-82f1002e71dd> in <module>
#       1 # Plot future predictions with confidence intervals
#       2 ax = m1.plot(label='observed', figsize=(20, 15))
# ----> 3 prediction.pred.plot(ax=ax, label='Forecast')
#       4 ax.fill_between(pred_conf.index,
#       5                 pred_conf.iloc[:, 0],
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/wrapper.py in __getattribute__(self, attr)
#      32             pass
#      33
# ---> 34         obj = getattr(results, attr)
#      35         data = results.model.data
#      36         how = self._wrap_attrs.get(attr)
#
# AttributeError: 'PredictionResults' object has no attribute 'pred'
